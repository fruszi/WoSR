# %% [markdown]
# # Main title
#
# Some text...
#
# * explanatory bullets

# %% [markdown]
# ## Set up Environment and Get Data

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Import packages
import numpy as np
import pandas as pd
import os
import urllib
import tarfile

# to ensure 'randomisation' is the same every time 
np.random.seed(5)

# Set up plotting
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# data source
data_url = "https://raw.github.com/fruszi/WoSR/master/ExerciseHealthDataSet.csv" 
# destination file names
data_file = "ExerciseHealthDataSet.csv"

# Saving figures
PROJECT_ROOT_DIR = os.getcwd()
#IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(PROJECT_ROOT_DIR, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# ignore warnings for now - not a good idea in general...
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# this below is is AZ-specific proxy

# %%
prox = {'http': 'http://ukapdlnx005.ukapd.astrazeneca.net:3128/'}
#create an opener object with the proxy defined in it
proxy = urllib.request.ProxyHandler(prox)
opener = urllib.request.build_opener(proxy)
urllib.request.install_opener(opener)

# %% [markdown]
# ### Load data

# %%
# download data, if not already
if not os.path.isfile(data_file):
    print('downloading file: {0}'.format(data_file))
    urllib.request.urlretrieve(data_url, data_file)
else:
    print('file already exists: {0}'.format(data_file))
# Out:
# file already exists: ExerciseHealthDataSet.csv

# %%
# load data
data_set = pd.read_csv(data_file)

# %% [markdown]
# #### Quick look

# %%
data_set.shape
# Out:
# (39242, 159)

# %%
# explore data a little
def basic_data_properties(dat):
    feature_count = dat.shape[1]
    cols = list(dat.columns.values)
    NA_count = dat.isnull().sum()
    dtypes = list(dat.dtypes)
    # create and view table with type and NA information
    pd.set_option("display.max_rows",feature_count) #pd.reset_option("^display")
    return pd.DataFrame({'colname': cols, 'dtype': dtypes, 'nas': NA_count}).reset_index(), feature_count, cols

# %%
props, feature_count, cols = basic_data_properties(data_set)
props
# Out:
#                         index                   colname    dtype    nas
# 0                   user_name                 user_name   object      0
# 1        raw_timestamp_part_1      raw_timestamp_part_1    int64      0
# 2        raw_timestamp_part_2      raw_timestamp_part_2    int64      0
# 3              cvtd_timestamp            cvtd_timestamp   object      0
# 4                  new_window                new_window   object      0
# 5                  num_window                num_window    int64      0
# 6                   roll_belt                 roll_belt  float64      0
# 7                  pitch_belt                pitch_belt  float64      0
# 8                    yaw_belt                  yaw_belt  float64      0
# 9            total_accel_belt          total_accel_belt    int64      0
# 10         kurtosis_roll_belt        kurtosis_roll_belt   object  38403
# 11        kurtosis_picth_belt       kurtosis_picth_belt   object  38403
# 12          kurtosis_yaw_belt         kurtosis_yaw_belt   object  38403
# 13         skewness_roll_belt        skewness_roll_belt   object  38403
# 14       skewness_roll_belt.1      skewness_roll_belt.1   object  38403
# 15          skewness_yaw_belt         skewness_yaw_belt   object  38403
# 16              max_roll_belt             max_roll_belt  float64  38403
# 17             max_picth_belt            max_picth_belt  float64  38403
# 18               max_yaw_belt              max_yaw_belt   object  38403
# 19              min_roll_belt             min_roll_belt  float64  38403
# 20             min_pitch_belt            min_pitch_belt  float64  38403
# 21               min_yaw_belt              min_yaw_belt   object  38403
# 22        amplitude_roll_belt       amplitude_roll_belt  float64  38403
# 23       amplitude_pitch_belt      amplitude_pitch_belt  float64  38403
# 24         amplitude_yaw_belt        amplitude_yaw_belt   object  38403
# 25       var_total_accel_belt      var_total_accel_belt  float64  38403
# 26              avg_roll_belt             avg_roll_belt  float64  38402
# 27           stddev_roll_belt          stddev_roll_belt  float64  38403
# 28              var_roll_belt             var_roll_belt  float64  38403
# 29             avg_pitch_belt            avg_pitch_belt  float64  38403
# 30          stddev_pitch_belt         stddev_pitch_belt  float64  38403
# 31             var_pitch_belt            var_pitch_belt  float64  38403
# 32               avg_yaw_belt              avg_yaw_belt  float64  38403
# 33            stddev_yaw_belt           stddev_yaw_belt  float64  38403
# 34               var_yaw_belt              var_yaw_belt  float64  38403
# 35               gyros_belt_x              gyros_belt_x  float64      0
# 36               gyros_belt_y              gyros_belt_y  float64      0
# 37               gyros_belt_z              gyros_belt_z  float64      0
# 38               accel_belt_x              accel_belt_x    int64      0
# 39               accel_belt_y              accel_belt_y    int64      0
# 40               accel_belt_z              accel_belt_z    int64      0
# 41              magnet_belt_x             magnet_belt_x    int64      0
# 42              magnet_belt_y             magnet_belt_y    int64      0
# 43              magnet_belt_z             magnet_belt_z    int64      0
# 44                   roll_arm                  roll_arm  float64      0
# 45                  pitch_arm                 pitch_arm  float64      0
# 46                    yaw_arm                   yaw_arm  float64      0
# 47            total_accel_arm           total_accel_arm    int64      0
# 48              var_accel_arm             var_accel_arm  float64  38403
# 49               avg_roll_arm              avg_roll_arm  float64  38403
# 50            stddev_roll_arm           stddev_roll_arm  float64  38403
# 51               var_roll_arm              var_roll_arm  float64  38403
# 52              avg_pitch_arm             avg_pitch_arm  float64  38403
# 53           stddev_pitch_arm          stddev_pitch_arm  float64  38403
# 54              var_pitch_arm             var_pitch_arm  float64  38403
# 55                avg_yaw_arm               avg_yaw_arm  float64  38403
# 56             stddev_yaw_arm            stddev_yaw_arm  float64  38403
# 57                var_yaw_arm               var_yaw_arm  float64  38403
# 58                gyros_arm_x               gyros_arm_x  float64      0
# 59                gyros_arm_y               gyros_arm_y  float64      0
# 60                gyros_arm_z               gyros_arm_z  float64      0
# 61                accel_arm_x               accel_arm_x    int64      0
# 62                accel_arm_y               accel_arm_y    int64      0
# 63                accel_arm_z               accel_arm_z    int64      0
# 64               magnet_arm_x              magnet_arm_x    int64      0
# 65               magnet_arm_y              magnet_arm_y    int64      0
# 66               magnet_arm_z              magnet_arm_z    int64      0
# 67          kurtosis_roll_arm         kurtosis_roll_arm   object  38403
# 68         kurtosis_picth_arm        kurtosis_picth_arm   object  38403
# 69           kurtosis_yaw_arm          kurtosis_yaw_arm   object  38403
# 70          skewness_roll_arm         skewness_roll_arm   object  38403
# 71         skewness_pitch_arm        skewness_pitch_arm   object  38403
# 72           skewness_yaw_arm          skewness_yaw_arm   object  38403
# 73               max_roll_arm              max_roll_arm  float64  38403
# 74              max_picth_arm             max_picth_arm  float64  38403
# 75                max_yaw_arm               max_yaw_arm  float64  38403
# 76               min_roll_arm              min_roll_arm  float64  38403
# 77              min_pitch_arm             min_pitch_arm  float64  38403
# 78                min_yaw_arm               min_yaw_arm  float64  38403
# 79         amplitude_roll_arm        amplitude_roll_arm  float64  38403
# 80        amplitude_pitch_arm       amplitude_pitch_arm  float64  38403
# 81          amplitude_yaw_arm         amplitude_yaw_arm  float64  38403
# 82              roll_dumbbell             roll_dumbbell  float64      1
# 83             pitch_dumbbell            pitch_dumbbell  float64      0
# 84               yaw_dumbbell              yaw_dumbbell  float64      0
# 85     kurtosis_roll_dumbbell    kurtosis_roll_dumbbell   object  38403
# 86    kurtosis_picth_dumbbell   kurtosis_picth_dumbbell   object  38403
# 87      kurtosis_yaw_dumbbell     kurtosis_yaw_dumbbell   object  38403
# 88     skewness_roll_dumbbell    skewness_roll_dumbbell   object  38403
# 89    skewness_pitch_dumbbell   skewness_pitch_dumbbell   object  38403
# 90      skewness_yaw_dumbbell     skewness_yaw_dumbbell   object  38403
# 91          max_roll_dumbbell         max_roll_dumbbell  float64  38403
# 92         max_picth_dumbbell        max_picth_dumbbell  float64  38403
# 93           max_yaw_dumbbell          max_yaw_dumbbell   object  38403
# 94          min_roll_dumbbell         min_roll_dumbbell  float64  38403
# 95         min_pitch_dumbbell        min_pitch_dumbbell  float64  38403
# 96           min_yaw_dumbbell          min_yaw_dumbbell   object  38403
# 97    amplitude_roll_dumbbell   amplitude_roll_dumbbell  float64  38403
# 98   amplitude_pitch_dumbbell  amplitude_pitch_dumbbell  float64  38403
# 99     amplitude_yaw_dumbbell    amplitude_yaw_dumbbell   object  38403
# 100      total_accel_dumbbell      total_accel_dumbbell    int64      0
# 101        var_accel_dumbbell        var_accel_dumbbell  float64  38403
# 102         avg_roll_dumbbell         avg_roll_dumbbell  float64  38403
# 103      stddev_roll_dumbbell      stddev_roll_dumbbell  float64  38403
# 104         var_roll_dumbbell         var_roll_dumbbell  float64  38403
# 105        avg_pitch_dumbbell        avg_pitch_dumbbell  float64  38403
# 106     stddev_pitch_dumbbell     stddev_pitch_dumbbell  float64  38403
# 107        var_pitch_dumbbell        var_pitch_dumbbell  float64  38403
# 108          avg_yaw_dumbbell          avg_yaw_dumbbell  float64  38403
# 109       stddev_yaw_dumbbell       stddev_yaw_dumbbell  float64  38403
# 110          var_yaw_dumbbell          var_yaw_dumbbell  float64  38403
# 111          gyros_dumbbell_x          gyros_dumbbell_x  float64      0
# 112          gyros_dumbbell_y          gyros_dumbbell_y  float64      0
# 113          gyros_dumbbell_z          gyros_dumbbell_z  float64      0
# 114          accel_dumbbell_x          accel_dumbbell_x    int64      0
# 115          accel_dumbbell_y          accel_dumbbell_y    int64      0
# 116          accel_dumbbell_z          accel_dumbbell_z    int64      0
# 117         magnet_dumbbell_x         magnet_dumbbell_x  float64      0
# 118         magnet_dumbbell_y         magnet_dumbbell_y  float64      0
# 119         magnet_dumbbell_z         magnet_dumbbell_z  float64      0
# 120              roll_forearm              roll_forearm  float64      0
# 121             pitch_forearm             pitch_forearm  float64      0
# 122               yaw_forearm               yaw_forearm  float64      0
# 123     kurtosis_roll_forearm     kurtosis_roll_forearm   object  38403
# 124    kurtosis_picth_forearm    kurtosis_picth_forearm   object  38403
# 125      kurtosis_yaw_forearm      kurtosis_yaw_forearm   object  38403
# 126     skewness_roll_forearm     skewness_roll_forearm   object  38403
# 127    skewness_pitch_forearm    skewness_pitch_forearm   object  38403
# 128      skewness_yaw_forearm      skewness_yaw_forearm   object  38403
# 129          max_roll_forearm          max_roll_forearm  float64  38403
# 130         max_picth_forearm         max_picth_forearm  float64  38403
# 131           max_yaw_forearm           max_yaw_forearm   object  38403
# 132          min_roll_forearm          min_roll_forearm  float64  38403
# 133         min_pitch_forearm         min_pitch_forearm  float64  38403
# 134           min_yaw_forearm           min_yaw_forearm   object  38403
# 135    amplitude_roll_forearm    amplitude_roll_forearm  float64  38403
# 136   amplitude_pitch_forearm   amplitude_pitch_forearm  float64  38403
# 137     amplitude_yaw_forearm     amplitude_yaw_forearm   object  38403
# 138       total_accel_forearm       total_accel_forearm    int64      0
# 139         var_accel_forearm         var_accel_forearm  float64  38403
# 140          avg_roll_forearm          avg_roll_forearm  float64  38403
# 141       stddev_roll_forearm       stddev_roll_forearm  float64  38403
# 142          var_roll_forearm          var_roll_forearm  float64  38403
# 143         avg_pitch_forearm         avg_pitch_forearm  float64  38403
# 144      stddev_pitch_forearm      stddev_pitch_forearm  float64  38403
# 145         var_pitch_forearm         var_pitch_forearm  float64  38403
# 146           avg_yaw_forearm           avg_yaw_forearm  float64  38403
# 147        stddev_yaw_forearm        stddev_yaw_forearm  float64  38403
# 148           var_yaw_forearm           var_yaw_forearm  float64  38403
# 149           gyros_forearm_x           gyros_forearm_x  float64      0
# 150           gyros_forearm_y           gyros_forearm_y  float64      0
# 151           gyros_forearm_z           gyros_forearm_z  float64      0
# 152           accel_forearm_x           accel_forearm_x  float64      0
# 153           accel_forearm_y           accel_forearm_y  float64      0
# 154           accel_forearm_z           accel_forearm_z    int64      0
# 155          magnet_forearm_x          magnet_forearm_x  float64      0
# 156          magnet_forearm_y          magnet_forearm_y  float64      0
# 157          magnet_forearm_z          magnet_forearm_z  float64      0
# 158                    classe                    classe   object      0

# %% [markdown]
# ### Explore and prepare training set

# %% [markdown]
# #### Split into training and test set

# %%
# do we need stratified split?
data_set["classe"].value_counts()/len(data_set)*100
# Out:
# A    28.436369
# B    19.349167
# E    18.383365
# C    17.440497
# D    16.390602
# Name: classe, dtype: float64

# %%
# we do, train_test_split does it already (used to be StratifiedShuffleSplit)
from sklearn.model_selection import train_test_split

training_set, test_set = train_test_split(data_set, test_size=0.2, random_state=2)

# %%
# let's see:
training_set["classe"].value_counts()/len(training_set)*100
# Out:
# A    28.455388
# B    19.361004
# E    18.220622
# C    17.322333
# D    16.640652
# Name: classe, dtype: float64

# %%
props, feature_count, cols = basic_data_properties(training_set)
props
# Out:
#                         index                   colname    dtype    nas
# 0                   user_name                 user_name   object      0
# 1        raw_timestamp_part_1      raw_timestamp_part_1    int64      0
# 2        raw_timestamp_part_2      raw_timestamp_part_2    int64      0
# 3              cvtd_timestamp            cvtd_timestamp   object      0
# 4                  new_window                new_window   object      0
# 5                  num_window                num_window    int64      0
# 6                   roll_belt                 roll_belt  float64      0
# 7                  pitch_belt                pitch_belt  float64      0
# 8                    yaw_belt                  yaw_belt  float64      0
# 9            total_accel_belt          total_accel_belt    int64      0
# 10         kurtosis_roll_belt        kurtosis_roll_belt   object  30729
# 11        kurtosis_picth_belt       kurtosis_picth_belt   object  30729
# 12          kurtosis_yaw_belt         kurtosis_yaw_belt   object  30729
# 13         skewness_roll_belt        skewness_roll_belt   object  30729
# 14       skewness_roll_belt.1      skewness_roll_belt.1   object  30729
# 15          skewness_yaw_belt         skewness_yaw_belt   object  30729
# 16              max_roll_belt             max_roll_belt  float64  30729
# 17             max_picth_belt            max_picth_belt  float64  30729
# 18               max_yaw_belt              max_yaw_belt   object  30729
# 19              min_roll_belt             min_roll_belt  float64  30729
# 20             min_pitch_belt            min_pitch_belt  float64  30729
# 21               min_yaw_belt              min_yaw_belt   object  30729
# 22        amplitude_roll_belt       amplitude_roll_belt  float64  30729
# 23       amplitude_pitch_belt      amplitude_pitch_belt  float64  30729
# 24         amplitude_yaw_belt        amplitude_yaw_belt   object  30729
# 25       var_total_accel_belt      var_total_accel_belt  float64  30729
# 26              avg_roll_belt             avg_roll_belt  float64  30729
# 27           stddev_roll_belt          stddev_roll_belt  float64  30729
# 28              var_roll_belt             var_roll_belt  float64  30729
# 29             avg_pitch_belt            avg_pitch_belt  float64  30729
# 30          stddev_pitch_belt         stddev_pitch_belt  float64  30729
# 31             var_pitch_belt            var_pitch_belt  float64  30729
# 32               avg_yaw_belt              avg_yaw_belt  float64  30729
# 33            stddev_yaw_belt           stddev_yaw_belt  float64  30729
# 34               var_yaw_belt              var_yaw_belt  float64  30729
# 35               gyros_belt_x              gyros_belt_x  float64      0
# 36               gyros_belt_y              gyros_belt_y  float64      0
# 37               gyros_belt_z              gyros_belt_z  float64      0
# 38               accel_belt_x              accel_belt_x    int64      0
# 39               accel_belt_y              accel_belt_y    int64      0
# 40               accel_belt_z              accel_belt_z    int64      0
# 41              magnet_belt_x             magnet_belt_x    int64      0
# 42              magnet_belt_y             magnet_belt_y    int64      0
# 43              magnet_belt_z             magnet_belt_z    int64      0
# 44                   roll_arm                  roll_arm  float64      0
# 45                  pitch_arm                 pitch_arm  float64      0
# 46                    yaw_arm                   yaw_arm  float64      0
# 47            total_accel_arm           total_accel_arm    int64      0
# 48              var_accel_arm             var_accel_arm  float64  30729
# 49               avg_roll_arm              avg_roll_arm  float64  30729
# 50            stddev_roll_arm           stddev_roll_arm  float64  30729
# 51               var_roll_arm              var_roll_arm  float64  30729
# 52              avg_pitch_arm             avg_pitch_arm  float64  30729
# 53           stddev_pitch_arm          stddev_pitch_arm  float64  30729
# 54              var_pitch_arm             var_pitch_arm  float64  30729
# 55                avg_yaw_arm               avg_yaw_arm  float64  30729
# 56             stddev_yaw_arm            stddev_yaw_arm  float64  30729
# 57                var_yaw_arm               var_yaw_arm  float64  30729
# 58                gyros_arm_x               gyros_arm_x  float64      0
# 59                gyros_arm_y               gyros_arm_y  float64      0
# 60                gyros_arm_z               gyros_arm_z  float64      0
# 61                accel_arm_x               accel_arm_x    int64      0
# 62                accel_arm_y               accel_arm_y    int64      0
# 63                accel_arm_z               accel_arm_z    int64      0
# 64               magnet_arm_x              magnet_arm_x    int64      0
# 65               magnet_arm_y              magnet_arm_y    int64      0
# 66               magnet_arm_z              magnet_arm_z    int64      0
# 67          kurtosis_roll_arm         kurtosis_roll_arm   object  30729
# 68         kurtosis_picth_arm        kurtosis_picth_arm   object  30729
# 69           kurtosis_yaw_arm          kurtosis_yaw_arm   object  30729
# 70          skewness_roll_arm         skewness_roll_arm   object  30729
# 71         skewness_pitch_arm        skewness_pitch_arm   object  30729
# 72           skewness_yaw_arm          skewness_yaw_arm   object  30729
# 73               max_roll_arm              max_roll_arm  float64  30729
# 74              max_picth_arm             max_picth_arm  float64  30729
# 75                max_yaw_arm               max_yaw_arm  float64  30729
# 76               min_roll_arm              min_roll_arm  float64  30729
# 77              min_pitch_arm             min_pitch_arm  float64  30729
# 78                min_yaw_arm               min_yaw_arm  float64  30729
# 79         amplitude_roll_arm        amplitude_roll_arm  float64  30729
# 80        amplitude_pitch_arm       amplitude_pitch_arm  float64  30729
# 81          amplitude_yaw_arm         amplitude_yaw_arm  float64  30729
# 82              roll_dumbbell             roll_dumbbell  float64      1
# 83             pitch_dumbbell            pitch_dumbbell  float64      0
# 84               yaw_dumbbell              yaw_dumbbell  float64      0
# 85     kurtosis_roll_dumbbell    kurtosis_roll_dumbbell   object  30729
# 86    kurtosis_picth_dumbbell   kurtosis_picth_dumbbell   object  30729
# 87      kurtosis_yaw_dumbbell     kurtosis_yaw_dumbbell   object  30729
# 88     skewness_roll_dumbbell    skewness_roll_dumbbell   object  30729
# 89    skewness_pitch_dumbbell   skewness_pitch_dumbbell   object  30729
# 90      skewness_yaw_dumbbell     skewness_yaw_dumbbell   object  30729
# 91          max_roll_dumbbell         max_roll_dumbbell  float64  30729
# 92         max_picth_dumbbell        max_picth_dumbbell  float64  30729
# 93           max_yaw_dumbbell          max_yaw_dumbbell   object  30729
# 94          min_roll_dumbbell         min_roll_dumbbell  float64  30729
# 95         min_pitch_dumbbell        min_pitch_dumbbell  float64  30729
# 96           min_yaw_dumbbell          min_yaw_dumbbell   object  30729
# 97    amplitude_roll_dumbbell   amplitude_roll_dumbbell  float64  30729
# 98   amplitude_pitch_dumbbell  amplitude_pitch_dumbbell  float64  30729
# 99     amplitude_yaw_dumbbell    amplitude_yaw_dumbbell   object  30729
# 100      total_accel_dumbbell      total_accel_dumbbell    int64      0
# 101        var_accel_dumbbell        var_accel_dumbbell  float64  30729
# 102         avg_roll_dumbbell         avg_roll_dumbbell  float64  30729
# 103      stddev_roll_dumbbell      stddev_roll_dumbbell  float64  30729
# 104         var_roll_dumbbell         var_roll_dumbbell  float64  30729
# 105        avg_pitch_dumbbell        avg_pitch_dumbbell  float64  30729
# 106     stddev_pitch_dumbbell     stddev_pitch_dumbbell  float64  30729
# 107        var_pitch_dumbbell        var_pitch_dumbbell  float64  30729
# 108          avg_yaw_dumbbell          avg_yaw_dumbbell  float64  30729
# 109       stddev_yaw_dumbbell       stddev_yaw_dumbbell  float64  30729
# 110          var_yaw_dumbbell          var_yaw_dumbbell  float64  30729
# 111          gyros_dumbbell_x          gyros_dumbbell_x  float64      0
# 112          gyros_dumbbell_y          gyros_dumbbell_y  float64      0
# 113          gyros_dumbbell_z          gyros_dumbbell_z  float64      0
# 114          accel_dumbbell_x          accel_dumbbell_x    int64      0
# 115          accel_dumbbell_y          accel_dumbbell_y    int64      0
# 116          accel_dumbbell_z          accel_dumbbell_z    int64      0
# 117         magnet_dumbbell_x         magnet_dumbbell_x  float64      0
# 118         magnet_dumbbell_y         magnet_dumbbell_y  float64      0
# 119         magnet_dumbbell_z         magnet_dumbbell_z  float64      0
# 120              roll_forearm              roll_forearm  float64      0
# 121             pitch_forearm             pitch_forearm  float64      0
# 122               yaw_forearm               yaw_forearm  float64      0
# 123     kurtosis_roll_forearm     kurtosis_roll_forearm   object  30729
# 124    kurtosis_picth_forearm    kurtosis_picth_forearm   object  30729
# 125      kurtosis_yaw_forearm      kurtosis_yaw_forearm   object  30729
# 126     skewness_roll_forearm     skewness_roll_forearm   object  30729
# 127    skewness_pitch_forearm    skewness_pitch_forearm   object  30729
# 128      skewness_yaw_forearm      skewness_yaw_forearm   object  30729
# 129          max_roll_forearm          max_roll_forearm  float64  30729
# 130         max_picth_forearm         max_picth_forearm  float64  30729
# 131           max_yaw_forearm           max_yaw_forearm   object  30729
# 132          min_roll_forearm          min_roll_forearm  float64  30729
# 133         min_pitch_forearm         min_pitch_forearm  float64  30729
# 134           min_yaw_forearm           min_yaw_forearm   object  30729
# 135    amplitude_roll_forearm    amplitude_roll_forearm  float64  30729
# 136   amplitude_pitch_forearm   amplitude_pitch_forearm  float64  30729
# 137     amplitude_yaw_forearm     amplitude_yaw_forearm   object  30729
# 138       total_accel_forearm       total_accel_forearm    int64      0
# 139         var_accel_forearm         var_accel_forearm  float64  30729
# 140          avg_roll_forearm          avg_roll_forearm  float64  30729
# 141       stddev_roll_forearm       stddev_roll_forearm  float64  30729
# 142          var_roll_forearm          var_roll_forearm  float64  30729
# 143         avg_pitch_forearm         avg_pitch_forearm  float64  30729
# 144      stddev_pitch_forearm      stddev_pitch_forearm  float64  30729
# 145         var_pitch_forearm         var_pitch_forearm  float64  30729
# 146           avg_yaw_forearm           avg_yaw_forearm  float64  30729
# 147        stddev_yaw_forearm        stddev_yaw_forearm  float64  30729
# 148           var_yaw_forearm           var_yaw_forearm  float64  30729
# 149           gyros_forearm_x           gyros_forearm_x  float64      0
# 150           gyros_forearm_y           gyros_forearm_y  float64      0
# 151           gyros_forearm_z           gyros_forearm_z  float64      0
# 152           accel_forearm_x           accel_forearm_x  float64      0
# 153           accel_forearm_y           accel_forearm_y  float64      0
# 154           accel_forearm_z           accel_forearm_z    int64      0
# 155          magnet_forearm_x          magnet_forearm_x  float64      0
# 156          magnet_forearm_y          magnet_forearm_y  float64      0
# 157          magnet_forearm_z          magnet_forearm_z  float64      0
# 158                    classe                    classe   object      0

# %%
pd.set_option("display.max_columns",feature_count)
training_set.head()
# Out:
#       user_name  raw_timestamp_part_1  raw_timestamp_part_2    cvtd_timestamp  \
# 34147   charles            1322837922                792350  02/12/2011 14:58
# 37160    eurico            1322489607                106710  28/11/2011 14:13
# 34387   charles            1322837904                284315  02/12/2011 14:58
# 8742     adelmo            1322832796                680362  02/12/2011 13:33
# 35570    jeremy            1322673118                766683  30/11/2011 17:11
#
#       new_window  num_window  roll_belt  pitch_belt  yaw_belt  \
# 34147         no         753     119.00       15.90     -1.07
# 37160         no         819       1.17        5.88    -87.60
# 34387         no         759     120.00       14.90      3.14
# 8742          no         198     122.00      -43.00    170.00
# 35570         no         785       0.45        5.03    -87.90
#
#        total_accel_belt kurtosis_roll_belt kurtosis_picth_belt  \
# 34147                18                NaN                 NaN
# 37160                 3                NaN                 NaN
# 34387                18                NaN                 NaN
# 8742                 17                NaN                 NaN
# 35570                 5                NaN                 NaN
#
#       kurtosis_yaw_belt skewness_roll_belt skewness_roll_belt.1  \
# 34147               NaN                NaN                  NaN
# 37160               NaN                NaN                  NaN
# 34387               NaN                NaN                  NaN
# 8742                NaN                NaN                  NaN
# 35570               NaN                NaN                  NaN
#
#       skewness_yaw_belt  max_roll_belt  max_picth_belt max_yaw_belt  \
# 34147               NaN            NaN             NaN          NaN
# 37160               NaN            NaN             NaN          NaN
# 34387               NaN            NaN             NaN          NaN
# 8742                NaN            NaN             NaN          NaN
# 35570               NaN            NaN             NaN          NaN
#
#        min_roll_belt  min_pitch_belt min_yaw_belt  amplitude_roll_belt  \
# 34147            NaN             NaN          NaN                  NaN
# 37160            NaN             NaN          NaN                  NaN
# 34387            NaN             NaN          NaN                  NaN
# 8742             NaN             NaN          NaN                  NaN
# 35570            NaN             NaN          NaN                  NaN
#
#        amplitude_pitch_belt amplitude_yaw_belt  var_total_accel_belt  \
# 34147                   NaN                NaN                   NaN
# 37160                   NaN                NaN                   NaN
# 34387                   NaN                NaN                   NaN
# 8742                    NaN                NaN                   NaN
# 35570                   NaN                NaN                   NaN
#
#        avg_roll_belt  stddev_roll_belt  var_roll_belt  avg_pitch_belt  \
# 34147            NaN               NaN            NaN             NaN
# 37160            NaN               NaN            NaN             NaN
# 34387            NaN               NaN            NaN             NaN
# 8742             NaN               NaN            NaN             NaN
# 35570            NaN               NaN            NaN             NaN
#
#        stddev_pitch_belt  var_pitch_belt  avg_yaw_belt  stddev_yaw_belt  \
# 34147                NaN             NaN           NaN              NaN
# 37160                NaN             NaN           NaN              NaN
# 34387                NaN             NaN           NaN              NaN
# 8742                 NaN             NaN           NaN              NaN
# 35570                NaN             NaN           NaN              NaN
#
#        var_yaw_belt  gyros_belt_x  gyros_belt_y  gyros_belt_z  accel_belt_x  \
# 34147           NaN          0.11          0.11         -0.15           -18
# 37160           NaN         -0.02          0.00         -0.02           -11
# 34387           NaN          0.14          0.10         -0.16           -19
# 8742            NaN          0.11          0.11         -0.16            48
# 35570           NaN          0.00         -0.02         -0.02           -15
#
#        accel_belt_y  accel_belt_z  magnet_belt_x  magnet_belt_y  \
# 34147            62          -162             29            597
# 37160             4            30             67            581
# 34387            65          -164             23            591
# 8742             44          -156            165            617
# 35570             1            43             56            636
#
#        magnet_belt_z  roll_arm  pitch_arm  yaw_arm  total_accel_arm  \
# 34147           -331     -57.4     -26.60     0.02               20
# 37160           -417      55.0      24.10    47.70               18
# 34387           -333     -28.8      -5.24   -37.30                6
# 8742            -303    -119.0      73.40   -42.10               30
# 35570           -296       0.0       0.00     0.00               21
#
#        var_accel_arm  avg_roll_arm  stddev_roll_arm  var_roll_arm  \
# 34147            NaN           NaN              NaN           NaN
# 37160            NaN           NaN              NaN           NaN
# 34387            NaN           NaN              NaN           NaN
# 8742             NaN           NaN              NaN           NaN
# 35570            NaN           NaN              NaN           NaN
#
#        avg_pitch_arm  stddev_pitch_arm  var_pitch_arm  avg_yaw_arm  \
# 34147            NaN               NaN            NaN          NaN
# 37160            NaN               NaN            NaN          NaN
# 34387            NaN               NaN            NaN          NaN
# 8742             NaN               NaN            NaN          NaN
# 35570            NaN               NaN            NaN          NaN
#
#        stddev_yaw_arm  var_yaw_arm  gyros_arm_x  gyros_arm_y  gyros_arm_z  \
# 34147             NaN          NaN         1.73        -1.03         1.00
# 37160             NaN          NaN         0.02         0.06         0.15
# 34387             NaN          NaN        -1.08         0.05         0.61
# 8742              NaN          NaN         0.11        -0.69         0.82
# 35570             NaN          NaN        -3.63         1.28        -0.64
#
#        accel_arm_x  accel_arm_y  accel_arm_z  magnet_arm_x  magnet_arm_y  \
# 34147          121         -122          -99           741           -21
# 37160          -72          155          -41           265            78
# 34387          -10          -53          -11           559           117
# 8742          -281          -62          -41          -300           273
# 35570           56           47         -195           743          -100
#
#        magnet_arm_z kurtosis_roll_arm kurtosis_picth_arm kurtosis_yaw_arm  \
# 34147            37               NaN                NaN              NaN
# 37160           610               NaN                NaN              NaN
# 34387           378               NaN                NaN              NaN
# 8742            602               NaN                NaN              NaN
# 35570           -80               NaN                NaN              NaN
#
#       skewness_roll_arm skewness_pitch_arm skewness_yaw_arm  max_roll_arm  \
# 34147               NaN                NaN              NaN           NaN
# 37160               NaN                NaN              NaN           NaN
# 34387               NaN                NaN              NaN           NaN
# 8742                NaN                NaN              NaN           NaN
# 35570               NaN                NaN              NaN           NaN
#
#        max_picth_arm  max_yaw_arm  min_roll_arm  min_pitch_arm  min_yaw_arm  \
# 34147            NaN          NaN           NaN            NaN          NaN
# 37160            NaN          NaN           NaN            NaN          NaN
# 34387            NaN          NaN           NaN            NaN          NaN
# 8742             NaN          NaN           NaN            NaN          NaN
# 35570            NaN          NaN           NaN            NaN          NaN
#
#        amplitude_roll_arm  amplitude_pitch_arm  amplitude_yaw_arm  \
# 34147                 NaN                  NaN                NaN
# 37160                 NaN                  NaN                NaN
# 34387                 NaN                  NaN                NaN
# 8742                  NaN                  NaN                NaN
# 35570                 NaN                  NaN                NaN
#
#        roll_dumbbell  pitch_dumbbell  yaw_dumbbell kurtosis_roll_dumbbell  \
# 34147     145.945531        9.954512     -4.971087                    NaN
# 37160      13.688321      -56.800589     98.244659                    NaN
# 34387    -107.490139      -43.960874     21.443225                    NaN
# 8742       59.006286      -21.453033    -93.259805                    NaN
# 35570      53.298775      -54.980781    -75.417251                    NaN
#
#       kurtosis_picth_dumbbell kurtosis_yaw_dumbbell skewness_roll_dumbbell  \
# 34147                     NaN                   NaN                    NaN
# 37160                     NaN                   NaN                    NaN
# 34387                     NaN                   NaN                    NaN
# 8742                      NaN                   NaN                    NaN
# 35570                     NaN                   NaN                    NaN
#
#       skewness_pitch_dumbbell skewness_yaw_dumbbell  max_roll_dumbbell  \
# 34147                     NaN                   NaN                NaN
# 37160                     NaN                   NaN                NaN
# 34387                     NaN                   NaN                NaN
# 8742                      NaN                   NaN                NaN
# 35570                     NaN                   NaN                NaN
#
#        max_picth_dumbbell max_yaw_dumbbell  min_roll_dumbbell  \
# 34147                 NaN              NaN                NaN
# 37160                 NaN              NaN                NaN
# 34387                 NaN              NaN                NaN
# 8742                  NaN              NaN                NaN
# 35570                 NaN              NaN                NaN
#
#        min_pitch_dumbbell min_yaw_dumbbell  amplitude_roll_dumbbell  \
# 34147                 NaN              NaN                      NaN
# 37160                 NaN              NaN                      NaN
# 34387                 NaN              NaN                      NaN
# 8742                  NaN              NaN                      NaN
# 35570                 NaN              NaN                      NaN
#
#        amplitude_pitch_dumbbell amplitude_yaw_dumbbell  total_accel_dumbbell  \
# 34147                       NaN                    NaN                     2
# 37160                       NaN                    NaN                    39
# 34387                       NaN                    NaN                     7
# 8742                        NaN                    NaN                    21
# 35570                       NaN                    NaN                    28
#
#        var_accel_dumbbell  avg_roll_dumbbell  stddev_roll_dumbbell  \
# 34147                 NaN                NaN                   NaN
# 37160                 NaN                NaN                   NaN
# 34387                 NaN                NaN                   NaN
# 8742                  NaN                NaN                   NaN
# 35570                 NaN                NaN                   NaN
#
#        var_roll_dumbbell  avg_pitch_dumbbell  stddev_pitch_dumbbell  \
# 34147                NaN                 NaN                    NaN
# 37160                NaN                 NaN                    NaN
# 34387                NaN                 NaN                    NaN
# 8742                 NaN                 NaN                    NaN
# 35570                NaN                 NaN                    NaN
#
#        var_pitch_dumbbell  avg_yaw_dumbbell  stddev_yaw_dumbbell  \
# 34147                 NaN               NaN                  NaN
# 37160                 NaN               NaN                  NaN
# 34387                 NaN               NaN                  NaN
# 8742                  NaN               NaN                  NaN
# 35570                 NaN               NaN                  NaN
#
#        var_yaw_dumbbell  gyros_dumbbell_x  gyros_dumbbell_y  gyros_dumbbell_z  \
# 34147               NaN              0.10              0.16             -0.05
# 37160               NaN              0.00              0.00              0.00
# 34387               NaN             -0.11              0.39             -0.05
# 8742                NaN              0.37              0.26             -0.05
# 35570               NaN              0.35              0.18             -0.39
#
#        accel_dumbbell_x  accel_dumbbell_y  accel_dumbbell_z  \
# 34147                 2                20                -1
# 37160              -205                52               317
# 34387               -30               -62                15
# 8742                -44               115              -166
# 35570              -145               141              -190
#
#        magnet_dumbbell_x  magnet_dumbbell_y  magnet_dumbbell_z  roll_forearm  \
# 34147             -389.0              485.0              -45.0         -74.7
# 37160             -423.0              226.0              310.0        -132.0
# 34387             -469.0              402.0               -2.0          44.6
# 8742              -504.0              367.0              -32.0           0.0
# 35570             -528.0              271.0              125.0         147.0
#
#        pitch_forearm  yaw_forearm kurtosis_roll_forearm  \
# 34147           32.9       -156.0                   NaN
# 37160          -64.5         69.7                   NaN
# 34387           19.0        -30.5                   NaN
# 8742             0.0          0.0                   NaN
# 35570           19.8        132.0                   NaN
#
#       kurtosis_picth_forearm kurtosis_yaw_forearm skewness_roll_forearm  \
# 34147                    NaN                  NaN                   NaN
# 37160                    NaN                  NaN                   NaN
# 34387                    NaN                  NaN                   NaN
# 8742                     NaN                  NaN                   NaN
# 35570                    NaN                  NaN                   NaN
#
#       skewness_pitch_forearm skewness_yaw_forearm  max_roll_forearm  \
# 34147                    NaN                  NaN               NaN
# 37160                    NaN                  NaN               NaN
# 34387                    NaN                  NaN               NaN
# 8742                     NaN                  NaN               NaN
# 35570                    NaN                  NaN               NaN
#
#        max_picth_forearm max_yaw_forearm  min_roll_forearm  min_pitch_forearm  \
# 34147                NaN             NaN               NaN                NaN
# 37160                NaN             NaN               NaN                NaN
# 34387                NaN             NaN               NaN                NaN
# 8742                 NaN             NaN               NaN                NaN
# 35570                NaN             NaN               NaN                NaN
#
#       min_yaw_forearm  amplitude_roll_forearm  amplitude_pitch_forearm  \
# 34147             NaN                     NaN                      NaN
# 37160             NaN                     NaN                      NaN
# 34387             NaN                     NaN                      NaN
# 8742              NaN                     NaN                      NaN
# 35570             NaN                     NaN                      NaN
#
#       amplitude_yaw_forearm  total_accel_forearm  var_accel_forearm  \
# 34147                   NaN                   50                NaN
# 37160                   NaN                   36                NaN
# 34387                   NaN                   12                NaN
# 8742                    NaN                   50                NaN
# 35570                   NaN                   33                NaN
#
#        avg_roll_forearm  stddev_roll_forearm  var_roll_forearm  \
# 34147               NaN                  NaN               NaN
# 37160               NaN                  NaN               NaN
# 34387               NaN                  NaN               NaN
# 8742                NaN                  NaN               NaN
# 35570               NaN                  NaN               NaN
#
#        avg_pitch_forearm  stddev_pitch_forearm  var_pitch_forearm  \
# 34147                NaN                   NaN                NaN
# 37160                NaN                   NaN                NaN
# 34387                NaN                   NaN                NaN
# 8742                 NaN                   NaN                NaN
# 35570                NaN                   NaN                NaN
#
#        avg_yaw_forearm  stddev_yaw_forearm  var_yaw_forearm  gyros_forearm_x  \
# 34147              NaN                 NaN              NaN            -0.24
# 37160              NaN                 NaN              NaN            -0.19
# 34387              NaN                 NaN              NaN            -0.32
# 8742               NaN                 NaN              NaN             0.79
# 35570              NaN                 NaN              NaN             0.00
#
#        gyros_forearm_y  gyros_forearm_z  accel_forearm_x  accel_forearm_y  \
# 34147             1.73             0.16           -447.0           -197.0
# 37160            -0.24             0.33            -61.0            278.0
# 34387             1.01             0.11            -70.0             95.0
# 8742             -2.36            -0.34           -175.0            452.0
# 35570             0.05            -0.10           -127.0            241.0
#
#        accel_forearm_z  magnet_forearm_x  magnet_forearm_y  magnet_forearm_z  \
# 34147               -3            -562.0            -170.0             248.0
# 37160              209            -416.0             923.0            -292.0
# 34387               -1            -108.0             724.0             505.0
# 8742               -64            -563.0             632.0             453.0
# 35570             -178            -603.0             604.0             659.0
#
#       classe
# 34147      D
# 37160      A
# 34387      C
# 8742       A
# 35570      C

# %% [markdown]
# #### Remove ID and time stamp variables
# move this to the beginning, to data_set

# %%
training_set = training_set[cols[6:]]

# %% [markdown]
# #### Data types

# %%
training_set.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('int64'), dtype('O')], dtype=object)

# %%
# some features have #DIV errors besides missing values, forcing dtype to be object 
training_set["kurtosis_yaw_belt"].unique()
# Out:
# array([nan, '#DIV/0!'], dtype=object)

# %% [markdown]
# #### Convert features to numeric
# this should go up to be applied to data_set

# %%
# replace DIV errors with nan
training_set = training_set.replace('#DIV/0!',np.nan)

# %%
# convert all but class label
training_set.iloc[:,1:-1] = training_set.iloc[:,1:-1].convert_objects(convert_numeric=True)

# %%
# the only remaining object is the class label
training_set.dtypes[training_set.dtypes=='object']
# Out:
# classe    object
# dtype: object

# %% [markdown]
# #### quick look at data

# %%
training_set.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# #### check how many missing datapoints we have

# %%
NA_ratio = training_set.isnull().sum() / len(training_set)
NA_ratio.hist(bins=50)
plt.show()

# %% [markdown]
# #### remove features where most of (> 95%) the values are missing

# %%
features_missing_values = training_set.isnull().sum() / len(training_set) > .95
features_drop = list(features_missing_values[features_missing_values].index)
training_set.drop(features_drop, axis=1, inplace=True)

# %%
training_set.shape
# Out:
# (31393, 53)

# %%
# check if there are ant NaNs left
props, feature_count, cols = basic_data_properties(training_set)
props
# Out:
#                    index               colname    dtype  nas
# 0              roll_belt             roll_belt  float64    0
# 1             pitch_belt            pitch_belt  float64    0
# 2               yaw_belt              yaw_belt  float64    0
# 3       total_accel_belt      total_accel_belt    int64    0
# 4           gyros_belt_x          gyros_belt_x  float64    0
# 5           gyros_belt_y          gyros_belt_y  float64    0
# 6           gyros_belt_z          gyros_belt_z  float64    0
# 7           accel_belt_x          accel_belt_x    int64    0
# 8           accel_belt_y          accel_belt_y    int64    0
# 9           accel_belt_z          accel_belt_z    int64    0
# 10         magnet_belt_x         magnet_belt_x    int64    0
# 11         magnet_belt_y         magnet_belt_y    int64    0
# 12         magnet_belt_z         magnet_belt_z    int64    0
# 13              roll_arm              roll_arm  float64    0
# 14             pitch_arm             pitch_arm  float64    0
# 15               yaw_arm               yaw_arm  float64    0
# 16       total_accel_arm       total_accel_arm    int64    0
# 17           gyros_arm_x           gyros_arm_x  float64    0
# 18           gyros_arm_y           gyros_arm_y  float64    0
# 19           gyros_arm_z           gyros_arm_z  float64    0
# 20           accel_arm_x           accel_arm_x    int64    0
# 21           accel_arm_y           accel_arm_y    int64    0
# 22           accel_arm_z           accel_arm_z    int64    0
# 23          magnet_arm_x          magnet_arm_x    int64    0
# 24          magnet_arm_y          magnet_arm_y    int64    0
# 25          magnet_arm_z          magnet_arm_z    int64    0
# 26         roll_dumbbell         roll_dumbbell  float64    1
# 27        pitch_dumbbell        pitch_dumbbell  float64    0
# 28          yaw_dumbbell          yaw_dumbbell  float64    0
# 29  total_accel_dumbbell  total_accel_dumbbell    int64    0
# 30      gyros_dumbbell_x      gyros_dumbbell_x  float64    0
# 31      gyros_dumbbell_y      gyros_dumbbell_y  float64    0
# 32      gyros_dumbbell_z      gyros_dumbbell_z  float64    0
# 33      accel_dumbbell_x      accel_dumbbell_x    int64    0
# 34      accel_dumbbell_y      accel_dumbbell_y    int64    0
# 35      accel_dumbbell_z      accel_dumbbell_z    int64    0
# 36     magnet_dumbbell_x     magnet_dumbbell_x  float64    0
# 37     magnet_dumbbell_y     magnet_dumbbell_y  float64    0
# 38     magnet_dumbbell_z     magnet_dumbbell_z  float64    0
# 39          roll_forearm          roll_forearm  float64    0
# 40         pitch_forearm         pitch_forearm  float64    0
# 41           yaw_forearm           yaw_forearm  float64    0
# 42   total_accel_forearm   total_accel_forearm    int64    0
# 43       gyros_forearm_x       gyros_forearm_x  float64    0
# 44       gyros_forearm_y       gyros_forearm_y  float64    0
# 45       gyros_forearm_z       gyros_forearm_z  float64    0
# 46       accel_forearm_x       accel_forearm_x  float64    0
# 47       accel_forearm_y       accel_forearm_y  float64    0
# 48       accel_forearm_z       accel_forearm_z    int64    0
# 49      magnet_forearm_x      magnet_forearm_x  float64    0
# 50      magnet_forearm_y      magnet_forearm_y  float64    0
# 51      magnet_forearm_z      magnet_forearm_z  float64    0
# 52                classe                classe   object    0

# %% [markdown]
# #### Separate features (predictors) and outcome (labels)

# %%
train_Y = pd.DataFrame(training_set["classe"])
train_X = training_set.drop("classe", axis=1)

# %% [markdown]
# #### Impute mean value(s) where we have missing data still

# %%
from sklearn.preprocessing import Imputer
# might want to look into MICEImputer at one point (multivar imputing) 

imputer = Imputer(strategy="median")

train_X = pd.DataFrame(imputer.fit_transform(train_X), columns=train_X.columns,
                       index = list(train_X.index.values))                           # returns array, not dataframe

# %%
training_set.hist(bins=50, figsize=(20,15))
#save_fig("attribute_histogram_plots")
plt.show()

# %%
train_X.iloc[:,0:12].hist(bins=50, figsize=(20,15), color='#830051')
save_fig("attribute_histogram_plots")
plt.show()
# Out:
# Saving figure attribute_histogram_plots

# %% [markdown]
# #### check correlations
# will have to review this
#
# RFECV

# %%
# check cor, kruskal and kruskalwallis too
from scipy.stats.stats import kendalltau

corr_array = []
for feature_ in train_X.columns.values:
    corr_array.append(kendalltau(train_X[feature_], train_Y['classe']).correlation)

# create an array with absolute values - so neg correlations are also sorted acording to strength  
abs_corr = [abs(coef) for coef in corr_array]

# %%
#take a look at the correlations
pd.DataFrame({'feature':train_X.columns.values,'abs_coef':abs_corr}).sort_values(by='abs_coef', ascending=False)
# Out:
#     abs_coef               feature
# 40  0.238016         pitch_forearm
# 23  0.204642          magnet_arm_x
# 24  0.189638          magnet_arm_y
# 20  0.186945           accel_arm_x
# 46  0.150368       accel_forearm_x
# 38  0.147866     magnet_dumbbell_z
# 11  0.145754         magnet_belt_y
# 49  0.143860      magnet_forearm_x
# 14  0.132490             pitch_arm
# 25  0.119656          magnet_arm_z
# 16  0.111890       total_accel_arm
# 36  0.110584     magnet_dumbbell_x
# 9   0.103838          accel_belt_z
# 12  0.100355         magnet_belt_z
# 0   0.097357             roll_belt
# 33  0.094668      accel_dumbbell_x
# 42  0.094148   total_accel_forearm
# 50  0.084368      magnet_forearm_y
# 22  0.072170           accel_arm_z
# 27  0.071547        pitch_dumbbell
# 3   0.069317      total_accel_belt
# 26  0.068801         roll_dumbbell
# 21  0.057299           accel_arm_y
# 2   0.056354              yaw_belt
# 35  0.052967      accel_dumbbell_z
# 39  0.046939          roll_forearm
# 1   0.036356            pitch_belt
# 37  0.036171     magnet_dumbbell_y
# 41  0.034828           yaw_forearm
# 51  0.033703      magnet_forearm_z
# 13  0.033618              roll_arm
# 7   0.031860          accel_belt_x
# 18  0.023453           gyros_arm_y
# 17  0.020864           gyros_arm_x
# 15  0.020838               yaw_arm
# 31  0.015475      gyros_dumbbell_y
# 47  0.013798       accel_forearm_y
# 8   0.012102          accel_belt_y
# 43  0.010629       gyros_forearm_x
# 30  0.009754      gyros_dumbbell_x
# 29  0.009685  total_accel_dumbbell
# 44  0.008380       gyros_forearm_y
# 19  0.007399           gyros_arm_z
# 6   0.007329          gyros_belt_z
# 32  0.006579      gyros_dumbbell_z
# 34  0.004641      accel_dumbbell_y
# 48  0.004271       accel_forearm_z
# 5   0.003447          gyros_belt_y
# 45  0.001689       gyros_forearm_z
# 28  0.001529          yaw_dumbbell
# 4   0.001128          gyros_belt_x
# 10  0.000723         magnet_belt_x

# %%
import seaborn as sns
#https://stackoverflow.com/questions/32992773/seaborn-specify-an-exact-color

sns.set(style="whitegrid", color_codes=True)
sns.boxplot(x="classe", y="pitch_forearm", data=pd.concat([train_X, train_Y["classe"]], axis=1));

# %%
features = train_X.columns.values
sns.set(rc={'figure.figsize':(11.7,8.27)}, style="whitegrid")
for i in range(1, 13):
    plt.subplot(4, 3, i)
    sns.boxplot(x="classe", y=features[i], data=pd.concat([train_X, train_Y["classe"]], axis=1))
                
save_fig("attribute_boxplots")
# Out:
# Saving figure attribute_boxplots

# %%
# plot relationships among some of the top features
from pandas.plotting import scatter_matrix

attributes = ["pitch_forearm", "magnet_arm_x", "magnet_belt_y",
              "magnet_arm_y"]
scatter_matrix(train_X[attributes], figsize=(12, 8), color='#830051')
save_fig("scatter_matrix_plot")
# Out:
# Saving figure scatter_matrix_plot

# %% [markdown]
# #### scale

# %%
#from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_X = pd.DataFrame(scaler.fit_transform(train_X), columns=train_X.columns,
                       index = list(train_X.index.values))                      # scaler returns array, not dataframe

# %% [markdown]
# #### remove features with 0 variance
# we don't have any here though. Either remove, or has to go up to before train-test split

# %%
from sklearn.feature_selection import VarianceThreshold

selector = VarianceThreshold()
train_X = pd.DataFrame(selector.fit_transform(train_X), columns=train_X.columns,
                       index = list(train_X.index.values))

# %% [markdown]
# #### label encoding

# %%
# or labelbinarizer for OvA below?
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
train_Ycat = pd.DataFrame(lb.fit_transform(train_Y), columns=train_Y.columns,
                          index = list(train_Y.index.values))

# %% [markdown]
# ## Model building and evaluation
# there is a crossval confusion matrix for each model - will not put in all in the final version
# confusion matrices per each model will also be arranged into a plot with subplots, instead of separate plots

# %% [markdown]
# ### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(random_state=2, solver='lbfgs')
#LogisticRegression(penalty='l2',C=.01)
log_reg.fit(train_X, train_Ycat)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=2, solver='lbfgs', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = log_reg.predict(train_X)

# %%
from sklearn.metrics import confusion_matrix
conf = confusion_matrix(train_Ycat, predictions)

# %%
#plt.rcParams['figure.figsize'] = (5,5)
#plt.rcParams.update(plt.rcParamsDefault)
import itertools

classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:,np.newaxis]                                    # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
conf

# %%
from sklearn.metrics import precision_recall_fscore_support
# other functions: precision_score, recall_score

#precision = precision_score(train_Ycat, predictions, average='weighted')
#recall = recall_score(train_Ycat, predictions, average='weighted')
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 73.49%
# Recall (sensitivity): 73.53%
# F1 score: 73.35%

# %% [markdown]
# #### Cross-validation

# %%
## crossval iterator
#from sklearn.cross_validation import ShuffleSplit
#cv = ShuffleSplit(train_X.shape[0], n_iter=3, test_size=0.2, random_state=2)

# %%
from sklearn.model_selection import cross_val_predict

train_Ycat = np.squeeze(train_Ycat)                                    # reshape labels to (rows,) from (rows,1)
predictions = cross_val_predict(log_reg, train_X, train_Ycat, cv=5)
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]                      # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 73.19%
# Recall (sensitivity): 73.24%
# F1 score: 73.05%

# %% [markdown]
# ### Support Vector Machine
# understand why this one is relatively weak (and leans towards the first class), or delete from final

# %%
from sklearn.linear_model import SGDClassifier
# radial basis function kernel/ kernel approximation
from sklearn.kernel_approximation import RBFSampler

# this actually doesn't help... have to read more about this
#rbf_feature = RBFSampler(gamma=1, random_state=1)
#train_X_rbf = rbf_feature.fit_transform(train_X)

sgd_clf = SGDClassifier(random_state=2)
sgd_clf.fit(train_X, train_Ycat)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=2, shuffle=True, verbose=0,
#        warm_start=False)

# %%
predictions = sgd_clf.predict(train_X)
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]                      # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 66.95%
# Recall (sensitivity): 66.30%
# F1 score: 66.41%

# %% [markdown]
# #### cross val

# %%
train_Ycat = np.squeeze(train_Ycat)                                    # reshape labels to (rows,) from (rows,1)
predictions = cross_val_predict(sgd_clf, train_X, train_Ycat, cv=5)
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]                      # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 63.35%
# Recall (sensitivity): 63.76%
# F1 score: 63.50%

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier()
tree_clf.fit(train_X, train_Ycat)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
predictions = tree_clf.predict(train_X)

# %%
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:,np.newaxis]                                    # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %% [markdown]
# #### cross val

# %%
train_Ycat = np.squeeze(train_Ycat)                                    # reshape labels to (rows,) from (rows,1)
predictions = cross_val_predict(tree_clf, train_X, train_Ycat, cv=5)
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:,np.newaxis]                                    # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 97.22%
# Recall (sensitivity): 97.22%
# F1 score: 97.22%

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

forest_clf = RandomForestClassifier(max_depth=10, random_state=2)
forest_clf.fit(train_X, train_Ycat)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=2,
#             verbose=0, warm_start=False)

# %%
predictions = forest_clf.predict(train_X)

# %%
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:,np.newaxis]                                    # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %% [markdown]
# #### cross val

# %%
train_Ycat = np.squeeze(train_Ycat)                                    # reshape labels to (rows,) from (rows,1)
predictions = cross_val_predict(forest_clf, train_X, train_Ycat, cv=5)
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:,np.newaxis]                                    # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 92.79%
# Recall (sensitivity): 92.45%
# F1 score: 92.48%

# %% [markdown]
# #### feature importance
# move this later to the selected model

# %%
feature_importance = pd.DataFrame(list(zip(strat_valid_X, forest_clf.feature_importances_)))
feature_importance.columns = ('feature','importance')
feature_importance.sort_values(by='importance', ascending=False)[0:9]

# %%
# what happens if we use the first X important features instead of all
#
#

# %% [markdown]
# ### XGboost

# %%
# in conda:
#git clone --recursive https://github.com/dmlc/xgboost

# %%
import xgboost as xgb

# model constructor
xgb_clf = xgb.XGBClassifier(colsample_bytree=0.8)
xgb_clf.fit(train_X, train_Ycat)
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
predictions = xgb_clf.predict(train_X)

# %%
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]                      # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %% [markdown]
# #### cross val

# %%
train_Ycat = np.squeeze(train_Ycat)                                    # reshape labels to (rows,) from (rows,1)
predictions = cross_val_predict(xgb_clf, train_X, train_Ycat, cv=3)    
conf = confusion_matrix(train_Ycat, predictions)

# %%
classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]                      # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))

# %%
feature_importance = pd.DataFrame(list(zip(train_X, xgb_clf.feature_importances_)))
feature_importance.columns = ('feature','importance')
#feature_importance['unit'] = (1/len(feature_importance))<feature_importance['importance']  # weight smaller than 1/num_features
feature_importance.sort_values(by='importance', ascending=False)[0:15]

# %% [markdown]
# #### trying to drop low weight features - doesn't improve model - leave out

# %%
sel_features = (feature_importance['feature'][feature_importance['unit']])

# %%
plt.plot(np.arange(len(feature_importance)),feature_importance['importance'].sort_values(ascending=False))

# %%
# train on selected features
xgb_clf.fit(train_X[sel_features], train_Ycat)

# %%
train_Ycat = np.squeeze(train_Ycat)                                    # reshape labels to (rows,) from (rows,1)
predictions = cross_val_predict(xgb_clf, train_X[sel_features], train_Ycat, cv=10)
conf = confusion_matrix(train_Ycat, predictions)

# %%
f1 = precision_recall_fscore_support(train_Ycat, predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))

# %% [markdown]
# ### Grid search and tuning - just started

# %% [markdown]
# #### can we tune log_reg?

# %%
# construct an iterator
from sklearn.cross_validation import ShuffleSplit
cv = ShuffleSplit(train_X.shape[0], n_iter=10, test_size=0.2, random_state=2)

# %%
from sklearn.grid_search import GridSearchCV

#Cs = np.arange(1,2)
multitype = ('ovr','multinomial')
classifier = GridSearchCV(estimator=log_reg, cv=cv, param_grid=dict(multi_class=multitype), n_jobs=-1)
classifier.fit(train_X, train_Ycat)
# Out:
# GridSearchCV(cv=ShuffleSplit(31393, n_iter=10, test_size=0.2, random_state=2),
#        error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=2, solver='lbfgs', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'multi_class': ('ovr', 'multinomial')},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
classifier.best_estimator_
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=2, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ### Diagnostics - learning curves
# will arrange into one plot with subplots

# %%
# to plot learning curve
from sklearn.learning_curve import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
train_X.size
# Out:
# 1632436

# %%
# log_reg
title = 'Learning Curves (log_reg, multi_class=%s)' %classifier.best_estimator_.multi_class
estimator = classifier.best_estimator_
plot_learning_curve(estimator, title, train_X, train_Y, cv=cv)
plt.show()

# %%
# forest_clf
title = 'Learning Curves (forest_clf)' 
estimator = forest_clf
plot_learning_curve(estimator, title, train_X, train_Y, cv=cv)
plt.show()

# %%
# tree_clf
title = 'Learning Curves (tree_clf)' 
estimator = tree_clf
plot_learning_curve(estimator, title, train_X, train_Y, cv=cv)
plt.show()

# %%
# xgb_clf
title = 'Learning Curves (xgb_clf)' 
estimator = xgb_clf
plot_learning_curve(estimator, title, train_X, train_Y, cv=cv)
plt.show()

# %% [markdown]
# ### Test a couple of them on the test set - ignore this for now

# %% [markdown]
# #### Apply preprocessing steps to test set

# %%
props, feature_count, cols = basic_data_properties(test_set)

test_set = test_set[cols[6:]]

# replace DIV errors with nan
test_set = test_set.replace('#DIV/0!',np.nan)

# convert all but class label
test_set.iloc[:,1:-1] = test_set.iloc[:,1:-1].convert_objects(convert_numeric=True)

features_missing_values = test_set.isnull().sum() / len(test_set) > .95
features_drop = list(features_missing_values[features_missing_values].index)
test_set.drop(features_drop, axis=1, inplace=True)

# %%
test_Y = pd.DataFrame(test_set["classe"])
test_X = test_set.drop("classe", axis=1) 

# imputer
test_X = pd.DataFrame(imputer.fit_transform(test_X), columns=test_X.columns,
                       index = list(test_X.index.values))                           # returns array, not dataframe

# scaling
test_X = pd.DataFrame(scaler.fit_transform(test_X), columns=test_X.columns,
                       index = list(test_X.index.values))  

# label encoding
test_Ycat = pd.DataFrame(lb.fit_transform(test_Y), columns=test_Y.columns,
                         index = list(test_Y.index.values))

# %% [markdown]
# ### Check log_reg

# %%
test_predictions = log_reg.predict(test_X)
conf = confusion_matrix(test_Ycat, test_predictions)

classes = np.unique(test_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:,np.newaxis]                                    # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(test_Ycat, test_predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 72.36%
# Recall (sensitivity): 72.37%
# F1 score: 72.19%

# %% [markdown]
# ### Check tree

# %%
test_predictions = tree_clf.predict(test_X)
conf = confusion_matrix(test_Ycat, test_predictions)

classes = np.unique(train_Y)
conf_norm = conf.astype('float') / conf.sum(axis=1)[:,np.newaxis]                                    # plot normalized matrix
plt.imshow(conf_norm, cmap=plt.cm.Reds, interpolation='None')
plt.colorbar()
plt.grid(False)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
fmt = '.2f' 
thresh = conf_norm.max() / 2.
for i, j in itertools.product(range(conf_norm.shape[0]), range(conf_norm.shape[1])):
    plt.text(j, i, format(conf_norm[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_norm[i, j] > thresh else "black")

#plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
f1 = precision_recall_fscore_support(test_Ycat, test_predictions, average='weighted')

print("Precision (accuracy): %.2f%%" % (f1[0] * 100.0))
print("Recall (sensitivity): %.2f%%" % (f1[1] * 100.0))
print("F1 score: %.2f%%" % (f1[2] * 100.0))
# Out:
# Precision (accuracy): 89.35%
# Recall (sensitivity): 89.20%
# F1 score: 89.21%
